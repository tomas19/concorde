# %%
import os
import pandas as pd
import geopandas as gpd
from pathlib import Path
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))

from plots import scatter_interpolate
from tools import curvature
from export import pointsInsidePoly
import warnings
warnings.filterwarnings("ignore")
from shapely.geometry import Polygon, Point, LineString
import dask
from tqdm.dask import TqdmCallback
import itertools
plt.style.use('dark_background')
plt.rcParams.update({'font.size': 16})
from matplotlib.offsetbox import AnchoredText
from pyproj import Geod
pd.set_option('display.max_rows', 100)
import numpy as np
# Out:
# <style>.container { width:98% !important; }</style>

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %% [markdown]
# ###### Select in and out Storms

# %%
df = pd.read_pickle(r'/home/tacuevas/Thesis/data/STORM/processed/STORM_NA_R4.pkl')

# %%
df.head()
# Out:
#    year  month  yr_tc_number  time_step  basin_id  lat   lon   min_press  \
# 0   0.0   10.0           0.0        0.0       1.0  8.9 -45.2  993.946699
# 1   0.0   10.0           0.0        1.0       1.0  9.0 -45.7  992.800000
# 2   0.0   10.0           0.0        2.0       1.0  9.1 -46.4  992.100000
# 3   0.0   10.0           0.0        3.0       1.0  9.2 -47.3  993.000000
# 4   0.0   10.0           0.0        4.0       1.0  9.3 -48.3  993.100000
#
#       max_ws  rad_to_max_ws  cat  landfall  dist_to_land  tc_number  \
# 0  20.371998      46.299999  0.0       0.0    851.946656          0
# 1  21.200000      45.905957  0.0       0.0    815.967429          0
# 2  21.700000      45.511914  0.0       0.0    766.103506          0
# 3  21.100000      45.117872  0.0       0.0    705.759651          0
# 4  20.900000      44.723829  0.0       0.0    647.548285          0
#
#     dist_to_NC  trajectory  forwardSpeed
# 0  4336.133140  281.309932     18.695934
# 1  4290.629311  278.130102     18.695934
# 2  4230.498007  276.340192     25.916882
# 3  4156.153101  275.710593     33.179142
# 4  4075.371766  281.309932     36.812210

# %%
nc = Point((-76.8, 35.2))
box = gpd.GeoDataFrame(geometry = [nc.buffer(6)])

# %%
pointsInside = pointsInsidePoly(list(zip(df['lon'].values, df['lat'].values)), list(box.geometry[0].boundary.coords))

# %%
df['in_instant'] = np.multiply(pointsInside, 1)

# %%
def get_longer_subdf(a):
    b = a[a['in_instant'] == 1]
    list_of_df = [d for _, d in b.groupby(b.index - np.arange(len(b)))]
    lengths = np.array([len(x) for x in list_of_df])
    idmax = np.argmax(lengths)
    
    return list_of_df[idmax]

# %%
@dask.delayed
def splitStorms(df, i):
    dfsub = df[df.tc_number == i]
    
    ## out
    if len(dfsub[dfsub['in_instant'] == 1]) == 0:
        a = [0]*len(dfsub)
    ## possible in
    else:
        ## out: track last less than 24 hrs and has less than 3 timestep is inside ROI
        if len(dfsub) < 8 or len(get_longer_subdf(dfsub)) < 3:
            a = [0]*len(dfsub)
        ## in
        else:
            a = [1]*len(dfsub)
    
    return a

tasks = [splitStorms(df, i) for i in df.tc_number.unique()]

with TqdmCallback(desc = "Spliting storms: in or out"):
    aux = dask.compute(tasks, scheduler = 'threads')

auxMerged = list(itertools.chain(*aux))
auxM = list(itertools.chain(*auxMerged))

df['in_all'] = auxM
# Out:
# Spliting storms: in or out: 100%|██████| 109479/109479 [07:49<00:00, 233.02it/s]

# %%
len(df[df['in_all'] == 1]['tc_number'].unique())
# Out:
# 9898

# %%
@dask.delayed
def attackTrajectory(df, i):
    dfsub = df[df.tc_number == i]
    
    if dfsub['in_all'].unique() == 0:
        val = 0
    else:
        long_dfsub = get_longer_subdf(dfsub)
        indIn = list(long_dfsub['in_instant']).index(1)
        val = long_dfsub.loc[long_dfsub.index[indIn], 'trajectory']

    return [val]*len(dfsub)

tasks = [attackTrajectory(df, i) for i in df['tc_number'].unique()]

with TqdmCallback(desc = "Computing trajectory of the storm when it enters ROI"):
    aux = dask.compute(tasks, scheduler = 'threads')

auxMerged = list(itertools.chain(*aux))
auxM = list(itertools.chain(*auxMerged))

df['in_roi_trajectory'] = auxM
# Out:
# Computing trajectory of the storm when it enters ROI: 100%|█| 109479/109479 [06:

# %%
df.describe().T
# Out:
#                        count          mean           std           min  \
# year               3507558.0   5013.666981   2883.095758  0.000000e+00
# month              3507558.0      8.501050      1.152267  6.000000e+00
# yr_tc_number       3507558.0      5.387186      3.854266  0.000000e+00
# time_step          3507558.0     30.418734     29.024408  0.000000e+00
# basin_id           3507558.0      1.000000      0.000000  1.000000e+00
# lat                3507558.0     24.060422     10.487971  5.100000e+00
# lon                3507558.0    -56.092493     18.358782 -1.049000e+02
# min_press          3507558.0    976.355539     19.766938  8.834000e+02
# max_ws             3507558.0     32.859786     12.039700  3.663698e+00
# rad_to_max_ws      3507558.0     48.397782     24.374266  9.260000e+00
# cat                3507558.0      1.183258      1.403300  0.000000e+00
# landfall           3507558.0      0.050373      0.218713  0.000000e+00
# dist_to_land       3507558.0    674.787889    546.491443  0.000000e+00
# tc_number          3507558.0  54789.793023  31608.225149  0.000000e+00
# dist_to_NC         3507558.0   2814.514756   1332.418380  1.294118e-12
# trajectory         3507558.0    197.750640    124.933472  0.000000e+00
# forwardSpeed       3507558.0     25.072088     15.168587  0.000000e+00
# in_instant         3507558.0      0.029507      0.169222  0.000000e+00
# in_all             3507558.0      0.114444      0.318350  0.000000e+00
# in_roi_trajectory  3507558.0     23.303572     80.286390  0.000000e+00
#
#                             25%           50%           75%            max
# year                2516.000000   5023.000000   7519.000000    9999.000000
# month                  8.000000      9.000000      9.000000      11.000000
# yr_tc_number           2.000000      5.000000      8.000000      24.000000
# time_step              8.000000     22.000000     45.000000     298.000000
# basin_id               1.000000      1.000000      1.000000       1.000000
# lat                   15.600000     22.200000     30.600000      59.900000
# lon                  -68.600000    -56.100000    -43.000000      -1.100000
# min_press            964.800000    981.400000    992.100000    1016.600000
# max_ws                22.800000     30.400000     40.900000      83.502870
# rad_to_max_ws         33.099575     44.384137     55.814197     444.480011
# cat                    0.000000      1.000000      2.000000       5.000000
# landfall               0.000000      0.000000      0.000000       1.000000
# dist_to_land         191.846352    557.380629   1110.437894    2146.290917
# tc_number          27290.000000  54924.000000  82215.000000  109478.000000
# dist_to_NC          1815.652848   2655.514093   3792.483122    7382.598611
# trajectory            63.434949    270.000000    300.963757     357.397438
# forwardSpeed          14.794040     22.225679     31.950380     154.388508
# in_instant             0.000000      0.000000      0.000000       1.000000
# in_all                 0.000000      0.000000      0.000000       1.000000
# in_roi_trajectory      0.000000      0.000000      0.000000     355.601295

# %%
df.isna().sum()
# Out:
# year                 0
# month                0
# yr_tc_number         0
# time_step            0
# basin_id             0
# lat                  0
# lon                  0
# min_press            0
# max_ws               0
# rad_to_max_ws        0
# cat                  0
# landfall             0
# dist_to_land         0
# tc_number            0
# dist_to_NC           0
# trajectory           0
# forwardSpeed         0
# in_instant           0
# in_all               0
# in_roi_trajectory    0
# dtype: int64

# %%
@dask.delayed
def meanTrajectory(df, i):
    dfsub = df[df.tc_number == i]
    
    if dfsub['in_all'].unique() == 0:
        val = 0
    
    else:
        long_dfsub = get_longer_subdf(dfsub)
#         indIn = list(long_dfsub['in_instant']).index(1)
#         indIn = dfsub[dfsub['in_instant'] == 1].index
        xs = [np.cos(np.deg2rad(a)) for a in long_dfsub.loc[:, 'trajectory']]
        ys = [np.sin(np.deg2rad(a)) for a in long_dfsub.loc[:, 'trajectory']]
        val = np.mod(np.rad2deg(np.arctan2(np.mean(ys), np.mean(xs))), 360)
    
    return [val]*len(dfsub)

tasks = [meanTrajectory(df, i) for i in df.tc_number.unique()]

with TqdmCallback(desc = "Computing distance"):
    aux = dask.compute(tasks, scheduler = 'threads')

auxMerged = list(itertools.chain(*aux))
auxM = list(itertools.chain(*auxMerged))

df['in_mean_trajectory'] = auxM
# Out:
# Computing distance: 100%|██████████████| 109479/109479 [06:12<00:00, 294.04it/s]

# %%
df.describe().T
# Out:
#                         count          mean           std           min  \
# year                3507558.0   5013.666981   2883.095758  0.000000e+00
# month               3507558.0      8.501050      1.152267  6.000000e+00
# yr_tc_number        3507558.0      5.387186      3.854266  0.000000e+00
# time_step           3507558.0     30.418734     29.024408  0.000000e+00
# basin_id            3507558.0      1.000000      0.000000  1.000000e+00
# lat                 3507558.0     24.060422     10.487971  5.100000e+00
# lon                 3507558.0    -56.092493     18.358782 -1.049000e+02
# min_press           3507558.0    976.355539     19.766938  8.834000e+02
# max_ws              3507558.0     32.859786     12.039700  3.663698e+00
# rad_to_max_ws       3507558.0     48.397782     24.374266  9.260000e+00
# cat                 3507558.0      1.183258      1.403300  0.000000e+00
# landfall            3507558.0      0.050373      0.218713  0.000000e+00
# dist_to_land        3507558.0    674.787889    546.491443  0.000000e+00
# tc_number           3507558.0  54789.793023  31608.225149  0.000000e+00
# dist_to_NC          3507558.0   2814.514756   1332.418380  1.294118e-12
# trajectory          3507558.0    197.750640    124.933472  0.000000e+00
# forwardSpeed        3507558.0     25.072088     15.168587  0.000000e+00
# in_instant          3507558.0      0.029507      0.169222  0.000000e+00
# in_all              3507558.0      0.114444      0.318350  0.000000e+00
# in_roi_trajectory   3507558.0     23.303572     80.286390  0.000000e+00
# in_mean_trajectory  3507558.0     21.043772     75.578437  0.000000e+00
#
#                              25%           50%           75%            max
# year                 2516.000000   5023.000000   7519.000000    9999.000000
# month                   8.000000      9.000000      9.000000      11.000000
# yr_tc_number            2.000000      5.000000      8.000000      24.000000
# time_step               8.000000     22.000000     45.000000     298.000000
# basin_id                1.000000      1.000000      1.000000       1.000000
# lat                    15.600000     22.200000     30.600000      59.900000
# lon                   -68.600000    -56.100000    -43.000000      -1.100000
# min_press             964.800000    981.400000    992.100000    1016.600000
# max_ws                 22.800000     30.400000     40.900000      83.502870
# rad_to_max_ws          33.099575     44.384137     55.814197     444.480011
# cat                     0.000000      1.000000      2.000000       5.000000
# landfall                0.000000      0.000000      0.000000       1.000000
# dist_to_land          191.846352    557.380629   1110.437894    2146.290917
# tc_number           27290.000000  54924.000000  82215.000000  109478.000000
# dist_to_NC           1815.652848   2655.514093   3792.483122    7382.598611
# trajectory             63.434949    270.000000    300.963757     357.397438
# forwardSpeed           14.794040     22.225679     31.950380     154.388508
# in_instant              0.000000      0.000000      0.000000       1.000000
# in_all                  0.000000      0.000000      0.000000       1.000000
# in_roi_trajectory       0.000000      0.000000      0.000000     355.601295
# in_mean_trajectory      0.000000      0.000000      0.000000     360.000000

# %%
df.isna().sum()
# Out:
# year                  0
# month                 0
# yr_tc_number          0
# time_step             0
# basin_id              0
# lat                   0
# lon                   0
# min_press             0
# max_ws                0
# rad_to_max_ws         0
# cat                   0
# landfall              0
# dist_to_land          0
# tc_number             0
# dist_to_NC            0
# trajectory            0
# forwardSpeed          0
# in_instant            0
# in_all                0
# in_roi_trajectory     0
# in_mean_trajectory    0
# dtype: int64

# %%
@dask.delayed
def curvature_parallel(df, i):
    dfsub = df[df.tc_number == i]
    
    if dfsub['in_all'].unique() == 0:
        val = 0
    else:
#         dfsub2 = dfsub[dfsub['in_instant'] == 1]
        dfsub2 = get_longer_subdf(dfsub)
        cur = curvature(dfsub2['lon'].values, dfsub2['lat'].values)
        val = np.nanmean(cur)
    
    return [val]*len(dfsub)

tasks = [curvature_parallel(df, i) for i in df.tc_number.unique()]

with TqdmCallback(desc = "Computing distance"):
    aux = dask.compute(tasks, scheduler = 'threads')

auxMerged = list(itertools.chain(*aux))
auxM = list(itertools.chain(*auxMerged))

df['in_curvature'] = auxM
# Out:
# Computing distance: 100%|██████████████| 109479/109479 [06:18<00:00, 289.61it/s]

# %%
df.describe().T
# Out:
#                         count          mean           std           min  \
# year                3507558.0   5013.666981   2883.095758  0.000000e+00
# month               3507558.0      8.501050      1.152267  6.000000e+00
# yr_tc_number        3507558.0      5.387186      3.854266  0.000000e+00
# time_step           3507558.0     30.418734     29.024408  0.000000e+00
# basin_id            3507558.0      1.000000      0.000000  1.000000e+00
# lat                 3507558.0     24.060422     10.487971  5.100000e+00
# lon                 3507558.0    -56.092493     18.358782 -1.049000e+02
# min_press           3507558.0    976.355539     19.766938  8.834000e+02
# max_ws              3507558.0     32.859786     12.039700  3.663698e+00
# rad_to_max_ws       3507558.0     48.397782     24.374266  9.260000e+00
# cat                 3507558.0      1.183258      1.403300  0.000000e+00
# landfall            3507558.0      0.050373      0.218713  0.000000e+00
# dist_to_land        3507558.0    674.787889    546.491443  0.000000e+00
# tc_number           3507558.0  54789.793023  31608.225149  0.000000e+00
# dist_to_NC          3507558.0   2814.514756   1332.418380  1.294118e-12
# trajectory          3507558.0    197.750640    124.933472  0.000000e+00
# forwardSpeed        3507558.0     25.072088     15.168587  0.000000e+00
# in_instant          3507558.0      0.029507      0.169222  0.000000e+00
# in_all              3507558.0      0.114444      0.318350  0.000000e+00
# in_roi_trajectory   3507558.0     23.303572     80.286390  0.000000e+00
# in_mean_trajectory  3507558.0     21.043772     75.578437  0.000000e+00
# in_curvature        3507558.0      0.026304      0.211686  0.000000e+00
#
#                              25%           50%           75%            max
# year                 2516.000000   5023.000000   7519.000000    9999.000000
# month                   8.000000      9.000000      9.000000      11.000000
# yr_tc_number            2.000000      5.000000      8.000000      24.000000
# time_step               8.000000     22.000000     45.000000     298.000000
# basin_id                1.000000      1.000000      1.000000       1.000000
# lat                    15.600000     22.200000     30.600000      59.900000
# lon                   -68.600000    -56.100000    -43.000000      -1.100000
# min_press             964.800000    981.400000    992.100000    1016.600000
# max_ws                 22.800000     30.400000     40.900000      83.502870
# rad_to_max_ws          33.099575     44.384137     55.814197     444.480011
# cat                     0.000000      1.000000      2.000000       5.000000
# landfall                0.000000      0.000000      0.000000       1.000000
# dist_to_land          191.846352    557.380629   1110.437894    2146.290917
# tc_number           27290.000000  54924.000000  82215.000000  109478.000000
# dist_to_NC           1815.652848   2655.514093   3792.483122    7382.598611
# trajectory             63.434949    270.000000    300.963757     357.397438
# forwardSpeed           14.794040     22.225679     31.950380     154.388508
# in_instant              0.000000      0.000000      0.000000       1.000000
# in_all                  0.000000      0.000000      0.000000       1.000000
# in_roi_trajectory       0.000000      0.000000      0.000000     355.601295
# in_mean_trajectory      0.000000      0.000000      0.000000     360.000000
# in_curvature            0.000000      0.000000      0.000000      13.132802

# %%
df.isna().sum()
# Out:
# year                  0
# month                 0
# yr_tc_number          0
# time_step             0
# basin_id              0
# lat                   0
# lon                   0
# min_press             0
# max_ws                0
# rad_to_max_ws         0
# cat                   0
# landfall              0
# dist_to_land          0
# tc_number             0
# dist_to_NC            0
# trajectory            0
# forwardSpeed          0
# in_instant            0
# in_all                0
# in_roi_trajectory     0
# in_mean_trajectory    0
# in_curvature          0
# dtype: int64

# %%
df.to_pickle(r"/home/tacuevas/Thesis/data/STORM/processed/STORM_NA_R4_InOut_v7.pkl")

# %%
@dask.delayed
def track2point(df, i):
    dfsub = df[(df.tc_number == i)]
    ## fill na values of trajectory
    dfsub = dfsub.fillna(method = 'ffill')
    indMinPress = dfsub['min_press'].idxmin()
    indMinDist = dfsub['dist_to_NC'].idxmin()
        
    l = [float(dfsub.year.unique()), #year
         float(dfsub.month.unique()), #month
         float(dfsub.yr_tc_number.unique()), #yearly tc number 
         dfsub.loc[indMinPress, 'time_step'], #ts min press
         dfsub.loc[indMinDist, 'time_step'], #ts min dist
         dfsub.loc[indMinPress, 'lat'], #lat min press
         dfsub.loc[indMinPress, 'lon'], # lon min press
         dfsub.loc[indMinDist, 'lat'], #lat min dist
         dfsub.loc[indMinDist, 'lon'], #lon min dist
         dfsub.loc[indMinDist, 'min_press'], #min press at min dist
         dfsub.loc[indMinPress, 'min_press'], #min press at min press
         dfsub.loc[indMinDist, 'max_ws'], #max ws at min dist
         dfsub.loc[indMinPress, 'max_ws'], #max ws at min press
         dfsub.loc[indMinDist, 'rad_to_max_ws'], #max rmw at min dist
         dfsub.loc[indMinPress, 'rad_to_max_ws'], #max rmw at min press
         dfsub.loc[indMinDist, 'forwardSpeed'], #f speed at min dist
         dfsub.loc[indMinPress, 'forwardSpeed'], #f speed at min press
         float(dfsub.cat.max()), #max category
         float(dfsub.landfall.max()),  #categorical landfall
         float(dfsub.tc_number.unique()), #tc number
         dfsub.loc[indMinDist, 'dist_to_NC'], #min dist to NC
         dfsub.loc[indMinPress, 'dist_to_NC'], #dist NC at min press
         dfsub.loc[indMinDist, 'trajectory'], #trajectory at min dist
         dfsub.loc[indMinPress, 'trajectory'], #trajectory at min press
         float(dfsub['in_roi_trajectory'].max()), #trajectory when entering roi
         float(dfsub['in_mean_trajectory'].max()), #mean trajectory inside roi
         float(dfsub['in_curvature'].max()), #mean curvature inside roi
         len(dfsub)*3, ## from number of timesteps to hours
         dfsub.loc[dfsub.index[0], 'lat'], #lat gen
         dfsub.loc[dfsub.index[0], 'lon']] #lon gen
    return l

dfin = df[df['in_all'] == 1]
tasks = [track2point(dfin, i) for i in dfin['tc_number'].unique()]
with TqdmCallback(desc = "Track 2 point"):
    aux = dask.compute(tasks, scheduler = 'threads')
# Out:
# Track 2 point: 100%|███████████████████████| 9898/9898 [01:00<00:00, 164.24it/s]

# %%
auxMerged = list(itertools.chain(*aux))
dfpnt = pd.DataFrame(auxMerged,
                     columns = ['year', 
                                'month', 
                                'yr_tc_number', 
                                'time_step_at_min_press', 
                                'time_step_at_min_distNC',
                                'lat_at_min_press', 
                                'lon_at_min_press', 
                                'lat_at_min_distNC', 
                                'lon_at_min_distNC',
                                'min_press_at_min_distNC', 
                                'min_press_at_min_press',
                                'max_ws_at_min_distNC', 
                                'max_ws_at_min_press',
                                'rad_to_max_ws_at_min_distNC', 
                                'rad_to_max_ws_at_min_press',
                                'forward_speed_at_min_distNC', 
                                'forward_speed_at_min_press',
                                'max_cat', 
                                'landfall', 
                                'tc_number', 
                                'distNC_at_min_distNC', 
                                'distNC_at_min_press',
                                'trajectory_at_min_distNC', 
                                'trajectory_at_min_press', 
                                'trajectory_in_roi',
                                'mean_trajectory_roi',
                                'mean_curvature_roi', 
                                'duration', 
                                'lat_gen', 
                                'lon_gen'])

geod = Geod(ellps="WGS84")
dfpnt['length'] = [geod.geometry_length(x)/1_000 for x in gdfIn.geometry]

# %%
dfpnt.describe().T
# Out:
#                               count          mean           std           min  \
# year                         9898.0   4975.200950   2890.861990  0.000000e+00
# month                        9898.0      8.488584      1.195171  6.000000e+00
# yr_tc_number                 9898.0      5.295514      3.851290  0.000000e+00
# time_step_at_min_press       9898.0     21.320974     18.602323  2.000000e+00
# time_step_at_min_distNC      9898.0     27.905435     27.592364  0.000000e+00
# lat_at_min_press             9898.0     30.460083      6.853791  8.300000e+00
# lon_at_min_press             9898.0    -69.921570     11.393120 -9.860000e+01
# lat_at_min_distNC            9898.0     33.982542      1.824335  2.930000e+01
# lon_at_min_distNC            9898.0    -75.826551      2.548399 -8.290000e+01
# min_press_at_min_distNC      9898.0    982.081921     19.254992  9.035000e+02
# min_press_at_min_press       9898.0    963.609497     24.492166  8.834000e+02
# max_ws_at_min_distNC         9898.0     29.979437     11.986558  9.470273e+00
# max_ws_at_min_press          9898.0     41.054841     13.894739  1.810000e+01
# rad_to_max_ws_at_min_distNC  9898.0     51.757458     25.885375  9.260000e+00
# rad_to_max_ws_at_min_press   9898.0     38.361361     16.768294  9.260000e+00
# forward_speed_at_min_distNC  9898.0     29.669815     12.163604  0.000000e+00
# forward_speed_at_min_press   9898.0     28.655665     14.251998  0.000000e+00
# max_cat                      9898.0      2.050818      1.696880  0.000000e+00
# landfall                     9898.0      0.714690      0.451585  0.000000e+00
# tc_number                    9898.0  54368.165791  31694.021097  4.000000e+00
# distNC_at_min_distNC         9898.0    308.294760    163.218825  1.294118e-12
# distNC_at_min_press          9898.0   1115.312254   1048.203490  1.294118e-12
# trajectory_at_min_distNC     9898.0    166.116047    138.822197  0.000000e+00
# trajectory_at_min_press      9898.0    191.515763    136.036601  0.000000e+00
# trajectory_in_roi            9898.0    194.058190    141.690906  0.000000e+00
# mean_trajectory_roi          9898.0    180.864913    142.246764  0.000000e+00
# mean_curvature_roi           9898.0      0.213648      0.528407  0.000000e+00
# duration                     9898.0    121.666700     87.521485  2.400000e+01
# lat_gen                      9898.0     23.668681      7.872185  5.200000e+00
# lon_gen                      9898.0    -65.988967     15.651914 -9.690000e+01
# length                       9898.0   3354.138601   2392.161858  6.421686e+01
#
#                                       25%           50%           75%  \
# year                          2490.000000   4949.500000   7497.750000
# month                            8.000000      9.000000      9.000000
# yr_tc_number                     2.000000      5.000000      8.000000
# time_step_at_min_press           8.000000     16.000000     29.000000
# time_step_at_min_distNC          8.000000     17.000000     43.000000
# lat_at_min_press                27.500000     31.300000     34.300000
# lon_at_min_press               -76.700000    -73.200000    -67.325000
# lat_at_min_distNC               32.700000     34.300000     35.200000
# lon_at_min_distNC              -77.600000    -75.600000    -73.900000
# min_press_at_min_distNC        970.800000    988.000000    997.400000
# min_press_at_min_press         946.800000    968.700000    984.100000
# max_ws_at_min_distNC            20.200000     26.900000     38.000000
# max_ws_at_min_press             29.400000     38.600000     51.600000
# rad_to_max_ws_at_min_distNC     37.040001     46.299999     61.115999
# rad_to_max_ws_at_min_press      27.780001     37.040001     46.299999
# forward_speed_at_min_distNC     21.918907     29.492620     37.103350
# forward_speed_at_min_press      18.771038     26.594279     35.472730
# max_cat                          1.000000      2.000000      4.000000
# landfall                         0.000000      1.000000      1.000000
# tc_number                    26997.250000  54063.000000  81963.750000
# distNC_at_min_distNC           170.202482    313.485236    444.370039
# distNC_at_min_press            448.192294    693.889066   1429.879111
# trajectory_at_min_distNC        36.869898     84.289407    315.000000
# trajectory_at_min_press         48.814075    279.462322    315.000000
# trajectory_in_roi               38.946249    287.354025    323.130102
# mean_trajectory_roi             37.648459    164.832286    324.363685
# mean_curvature_roi               0.043495      0.084182      0.171025
# duration                        51.000000     99.000000    171.000000
# lat_gen                         16.800000     26.000000     29.900000
# lon_gen                        -76.500000    -72.700000    -58.300000
# length                        1306.963621   2701.663844   5258.180454
#
#                                        max
# year                           9999.000000
# month                            11.000000
# yr_tc_number                     22.000000
# time_step_at_min_press          188.000000
# time_step_at_min_distNC         234.000000
# lat_at_min_press                 59.900000
# lon_at_min_press                 -1.200000
# lat_at_min_distNC                40.100000
# lon_at_min_distNC               -70.800000
# min_press_at_min_distNC        1010.400000
# min_press_at_min_press         1001.500000
# max_ws_at_min_distNC             71.600000
# max_ws_at_min_press              83.502870
# rad_to_max_ws_at_min_distNC     444.480011
# rad_to_max_ws_at_min_press      166.679993
# forward_speed_at_min_distNC     112.175674
# forward_speed_at_min_press      118.217878
# max_cat                           5.000000
# landfall                          1.000000
# tc_number                    109478.000000
# distNC_at_min_distNC            655.343435
# distNC_at_min_press            6699.565591
# trajectory_at_min_distNC        356.423666
# trajectory_at_min_press         356.423666
# trajectory_in_roi               355.601295
# mean_trajectory_roi             360.000000
# mean_curvature_roi               13.132802
# duration                        828.000000
# lat_gen                          41.000000
# lon_gen                         -18.900000
# length                        17865.005141

# %%
dfpnt.to_pickle(r"/home/tacuevas/Thesis/data/STORM/processed/STORM_NA_R4_In_pnt_v7.pkl")

# %%
geom = []
dfin = df[df['in_all'] == 1]
for i in tqdm(dfin.tc_number.unique()):
    subdf = dfin[dfin.tc_number == i]
    lstring = LineString(list(zip(subdf.lon, subdf.lat)))
    geom.append(lstring)
    
gdfIn = gpd.GeoDataFrame(geometry = geom, crs = 4326)

for col in dfpnt.columns:
    gdfIn[col] = dfpnt[col].values
    
gdfIn.to_file(r"../gis/gpkg/STORM_NA_R4_IN_v7.gpkg")
# Out:
# 100%|█████████████████████████████████████| 9898/9898 [00:06<00:00, 1544.25it/s]

# %%
geom = []
dfout = df[df['in_all'] == 0]
for i in tqdm(dfout.tc_number.unique()):
    subdf = dfout[dfout.tc_number == i]
    lstring = LineString(list(zip(subdf.lon, subdf.lat)))
    geom.append(lstring)

gdfOut = gpd.GeoDataFrame(geometry = geom, crs = 4326)
gdfOut.to_file(r"../gis/gpkg/STORM_NA_R4_Out_v7.gpkg")
# Out:
# 100%|████████████████████████████████████| 99581/99581 [05:13<00:00, 317.78it/s]

# %% [markdown]
# ##### Plots

# %%
df = pd.read_pickle(r"../data/STORM/processed/STORM_NA_R4_InOut_v7.pkl")
dfworld = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
nc = Point((-76.8, 35.2))
gdfIn = gpd.read_file(r"../gis/gpkg/STORM_NA_R4_IN_v7.gpkg")
gdfOut = gpd.read_file(r"../gis/gpkg/STORM_NA_R4_Out_v7.gpkg")
box = gpd.GeoDataFrame(geometry = [nc.buffer(6)])

# %%
a = df.groupby('tc_number')['dist_to_NC'].idxmin()
dfNC = df.loc[a, :]

x = dfNC.loc[:, 'lon'].values
y = dfNC.loc[:, 'lat'].values
z = scatter_interpolate(x,y)
idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]
cm = plt.cm.get_cmap('viridis')
fig, ax = plt.subplots(figsize = (20, 20))

dfworld.plot(ax = ax, color = 'grey', alpha = 0.5)
dfworld.boundary.plot(ax = ax, color = 'w')
ax.scatter(x, y, c = z, cmap = cm, alpha = 0.5)
box.boundary.plot(ax = ax, color = 'r')
ax.plot([-76.8], [35.2], color = 'r', marker = '*')
ax.set_xlim([-105, 0])
ax.set_ylim([0, 55])
ax.set_aspect('equal')
ax.set_xlabel('Longitude [deg]')
ax.set_ylabel('Latitude [deg]')
ax.set_title('Closest point to NC of each storm in the STORM dataset')

# text = AnchoredText(nb_name, 'upper right',frameon = False, borderpad = -2, prop=dict(fontsize = 'xx-small', alpha = 0.4))
# ax.add_artist(text)
# Out:
# Text(0.5, 1.0, 'Closest point to NC of each storm in the STORM dataset')

# %%
dfgen = df[(df.time_step == 0) & (df['in_all'] == 1)]
dfworld = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
x = dfgen.loc[:, 'lon'].values
y = dfgen.loc[:, 'lat'].values
z = scatter_interpolate(x,y)
idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]
# cm = plt.cm.get_cmap('viridis')
cm = plt.cm.get_cmap('viridis')
fig, ax = plt.subplots(figsize = (20, 20))

dfworld.plot(ax = ax, color = 'grey', alpha = 0.5)
dfworld.boundary.plot(ax = ax, color = 'w')
ax.scatter(x, y, c = z, cmap = cm, alpha = 0.5)
box.boundary.plot(ax = ax, color = 'r')
ax.plot([-76.8], [35.2], color = 'r', marker = '*')
ax.set_xlim([-105, 0])
ax.set_ylim([0, 55])
ax.set_aspect('equal')
ax.set_xlabel('Longitude [deg]')
ax.set_ylabel('Latitude [deg]')
ax.set_title('Genesis location of considered storms')

# text = AnchoredText(nb_name, 'upper right',frameon = False, borderpad = -2, prop=dict(fontsize = 'xx-small', alpha = 0.4))
# ax.add_artist(text)
# Out:
# Text(0.5, 1.0, 'Genesis location of considered storms')

# %%
# gdfall = pd.concat([gdfIn, gdOout], axis = 0)
fig, ax = plt.subplots(figsize = (20, 20))
dfworld.plot(ax = ax, color = 'grey', alpha = 0.5)
gdfOut.plot(ax = ax, alpha = 0.1, color = 'orange')
gdfIn.plot(ax = ax, alpha = 0.5, column = 'max_cat', cmap = 'viridis', legend = True, categorical = True)
dfworld.boundary.plot(ax = ax, color = 'w')
box.boundary.plot(ax = ax, color = 'r')
ax.plot([-76.8], [35.2], color = 'r', marker = '*')


ax.set_xlim([-110, 10])
ax.set_ylim([0, 65])
ax.set_aspect('equal')
ax.set_xlabel('Longitude [deg]')
ax.set_ylabel('Latitude [deg]')
ax.set_title('Track of all storms in the STORM dataset')

leg = ax.get_legend()
leg.get_frame().set_edgecolor('k')
leg.get_frame().set_facecolor('w')
# leg.set_frameon(True)
# leg.set_bbox_to_anchor((1.15,0.5))

text = AnchoredText(nb_name, 'upper right', frameon = False, borderpad = -2, prop=dict(fontsize = 'xx-small', alpha = 0.4))
ax.add_artist(text)

# %%
dfsub.iloc[[0], :]
# Out:
#      year  month  yr_tc_number  time_step  basin_id   lat   lon   min_press  \
# 125   0.0   11.0           4.0        0.0       1.0  22.1 -67.9  996.722057
#
#         max_ws  rad_to_max_ws  ...  dist_to_land  tc_number   dist_to_NC  \
# 125  20.371998      74.080002  ...    337.632304          4  1690.713296
#
#      trajectory  forwardSpeed  in_instant  in_all  in_roi_trajectory  \
# 125  300.963757      18.30546           0       1         296.565051
#
#      in_mean_trajectory  in_curvature
# 125          289.913772      0.548779
#
# [1 rows x 22 columns]

# %%
dfsub = df[df['tc_number'] == 4]
dfworld = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
color_var = 'trajectory'

fig, ax = plt.subplots(figsize = (20, 20), nrows = 2)
dfworld.plot(ax = ax[0], color = 'grey', alpha = 0.5)
dfsub.plot.scatter(x = 'lon', y = 'lat', ax = ax[0], c = color_var, cmap = 'viridis')
dfsub.iloc[[0], :].plot.scatter(x = 'lon', y = 'lat', ax = ax[0], marker = '*', s = 100, c = 'r')
dfworld.boundary.plot(ax = ax[0], color = 'w')
box.boundary.plot(ax = ax[0], color = 'r')
ax[0].set_xlim([-105, 0])
ax[0].set_ylim([0, 55])
ax[0].set_aspect('equal')

dfworld.plot(ax = ax[1], color = 'grey', alpha = 0.5)
dfsub.plot(x = 'lon', y = 'lat', ax = ax[1], color = 'w', alpha = 0.5, label = '__nolegend__', legend = False)
dfsub.plot.scatter(x = 'lon', y = 'lat', ax = ax[1], c = color_var, cmap = 'viridis', s = 100)
dfworld.boundary.plot(ax = ax[1], color = 'w')
box.boundary.plot(ax = ax[1], color = 'r')
ax[1].set_xlim([-84, -70])
ax[1].set_ylim([28, 42])
ax[1].set_aspect('equal')

ax[0].set_xlabel('Longitude [deg]')
ax[0].set_ylabel('Latitude [deg]')

ax[1].set_xlabel('Longitude [deg]')
ax[1].set_ylabel('Latitude [deg]')
# Out:
# Text(147.875, 0.5, 'Latitude [deg]')
