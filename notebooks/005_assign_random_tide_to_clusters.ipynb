# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path
import geopandas as gpd
from tqdm import tqdm
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
plt.rcParams.update({'font.size': 14})
from matplotlib.offsetbox import AnchoredText
from IPython.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))

from calendar import monthrange
import datetime
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>.container { width:98% !important; }</style>

# %% [markdown]
# ###### Assign random date

# %%
pathin = Path(r'../data/STORM/processed')
dfall = pd.read_pickle(pathin/'STORM_NA_R4.pkl')

# %%
dfcl = pd.read_pickle(pathin/'STORM_NA_R4_In_pnt_v6_MDAvec_12params_1000.pkl')

# %%
dfcl.head()
# Out:
#    lat_at_min_distNC  lon_at_min_distNC  min_press_at_min_distNC  \
# 0               35.3              -74.2               997.300000
# 1               33.1              -71.4               924.800000
# 2               32.7              -71.9              1001.576427
# 3               37.5              -76.4               993.300000
# 4               35.0              -77.0               996.500000
#
#    rad_to_max_ws_at_min_distNC  forward_speed_at_min_distNC  landfall  \
# 0                    51.444446                    22.997927       0.0
# 1                    13.581333                    44.791196       1.0
# 2                   166.679993                    90.538476       0.0
# 3                   132.398292                    36.181619       1.0
# 4                    28.573715                     4.790183       1.0
#
#    trajectory_in_roi  mean_trajectory_roi  mean_curvature_roi  duration  \
# 0         210.963757           168.218203            0.248986     111.0
# 1          26.565051            29.621220            0.018094     276.0
# 2          33.690068            42.968477            0.138030     117.0
# 3         299.054604           283.776639            0.043328     216.0
# 4         341.565051           327.264810            1.203544      30.0
#
#    lat_gen  lon_gen  index_cluster    weight  npoints  tc_number
# 0     36.4    -73.7           3384  0.000204        2    37378.0
# 1     11.9    -37.5           5962  0.000612        6    65593.0
# 2     32.7    -71.9           9400  0.000102        1   105184.0
# 3      6.7    -28.7           4260  0.000306        3    46863.0
# 4     33.8    -76.9           7518  0.004489       44    83738.0

# %%
## full data of selected storms
dfallsub = dfall.loc[dfall['tc_number'].isin(dfcl['tc_number']), :]

# %%
## count number of storms per year

# %%
dfall.head()
# Out:
#    year  month  yr_tc_number  time_step  basin_id  lat   lon   min_press  \
# 0   0.0   10.0           0.0        0.0       1.0  8.9 -45.2  993.946699
# 1   0.0   10.0           0.0        1.0       1.0  9.0 -45.7  992.800000
# 2   0.0   10.0           0.0        2.0       1.0  9.1 -46.4  992.100000
# 3   0.0   10.0           0.0        3.0       1.0  9.2 -47.3  993.000000
# 4   0.0   10.0           0.0        4.0       1.0  9.3 -48.3  993.100000
#
#       max_ws  rad_to_max_ws  cat  landfall  dist_to_land  tc_number  \
# 0  20.371998      46.299999  0.0       0.0    851.946656          0
# 1  21.200000      45.905957  0.0       0.0    815.967429          0
# 2  21.700000      45.511914  0.0       0.0    766.103506          0
# 3  21.100000      45.117872  0.0       0.0    705.759651          0
# 4  20.900000      44.723829  0.0       0.0    647.548285          0
#
#     dist_to_NC  trajectory  forwardSpeed
# 0  4336.133140  281.309932     18.695934
# 1  4290.629311  278.130102     18.695934
# 2  4230.498007  276.340192     25.916882
# 3  4156.153101  275.710593     33.179142
# 4  4075.371766  281.309932     36.812210

# %%
nstorms_per_year = dfall.groupby(['year'])['yr_tc_number'].max()

# %%
mean_val = nstorms_per_year.mean()
std_val = nstorms_per_year.std()

# %%
mean_val
# Out:
# 9.7065

# %%
std_val
# Out:
# 3.2459838864570965

# %%
exe_id = np.random.randint(0, 99)

# %%
exe_id
# Out:
# 0

# %%
dfcl2 = dfcl.copy()
dfout = pd.DataFrame()
for yr in tqdm(np.arange(2020, 1800, -1)):
    ## select random number storms for year yr
    n = np.random.randint(int(mean_val - std_val), int(mean_val + std_val))
    ## select random storms
    try:
        dfcls = dfcl2.sample(n)
    except:
        ## there are less storms without date assigned than n
        dfcls = dfcl2.copy()
    
    for i in range(len(dfcls)):
        dfa = dfallsub[dfallsub['tc_number'] == dfcls['tc_number'].iloc[i]]
        ndays = monthrange(yr, int(dfa['month'].unique()))[1]
        dummy = 0
        i = 0
        while dummy == 0:
            startday = np.random.randint(1, ndays)
            starthour = np.random.randint(0, 23)
            dfa.loc[:, 'date'] = pd.date_range(start = datetime.datetime(yr, int(dfa['month'].unique()), startday, starthour), periods = len(dfa), freq = '3H')
            aux = np.array([x.month for x in dfa['date']])
            l = aux[aux == dfa['month'].unique()]
            if len(l) > 3*len(dfa)/4:
                dummy = 1
#                 print(f'Done with {i} iterations')
        dfout = pd.concat([dfout, dfa])
    ## delete selected updated storms
    dfcl2 = dfcl2.drop(dfcls.index, axis = 'rows')
    
    if len(dfcl2) == 0:
        break
dfallsub['random_date'] = dfout.loc[dfallsub.index, 'date']

dfallsub.to_pickle(pathin/f'STORM_NA_R4_In_pnt_v6_MDAvec_12params_1000_map_original_ts_exec{exe_id:02d}.pkl')
# Out:
#  50%|█████████████████████████████████████                                     | 110/220 [00:03<00:03, 36.60it/s]

# %% [markdown]
# ###### Get tide information

# %%
pathin = Path(r'../data/STORM/processed')
df = pd.read_pickle(pathin/f'STORM_NA_R4_In_pnt_v6_MDAvec_12params_1000_map_original_ts_exec{exe_id:02d}.pkl')

# %%
df.head()
# Out:
#       year  month  yr_tc_number  time_step  basin_id   lat   lon   min_press  \
# 4454  12.0    6.0          14.0        0.0       1.0  22.8 -95.5  991.109469
# 4455  12.0    6.0          14.0        1.0       1.0  22.8 -95.2  991.000000
# 4456  12.0    6.0          14.0        2.0       1.0  22.7 -95.0  989.900000
# 4457  12.0    6.0          14.0        3.0       1.0  22.6 -94.7  987.900000
# 4458  12.0    6.0          14.0        4.0       1.0  22.4 -94.2  985.000000
#
#          max_ws  rad_to_max_ws  cat  landfall  dist_to_land  tc_number  \
# 4454  20.371998      37.040001  0.0       0.0    244.279646        136
# 4455  20.400000      37.040001  0.0       0.0    272.553045        136
# 4456  21.200000      37.040001  0.0       0.0    286.965024        136
# 4457  22.400000      37.040001  0.0       0.0    313.049588        136
# 4458  24.200000      37.040001  0.0       0.0    358.993825        136
#
#        dist_to_NC  trajectory  forwardSpeed         random_date
# 4454  2275.313101   90.000000     18.103784 1963-06-11 12:00:00
# 4455  2252.246345  116.565051     10.267294 1963-06-11 15:00:00
# 4456  2244.362245  108.434949      7.778969 1963-06-11 18:00:00
# 4457  2229.085682  111.801409     10.921224 1963-06-11 21:00:00
# 4458  2206.824420   90.000000     18.670866 1963-06-12 00:00:00

# %%
for itc, tc in tqdm(enumerate(df['tc_number'].unique())):
    dfs = df[df['tc_number'] == tc]
    dur = (dfs['random_date'].iloc[-1] - dfs['random_date'].iloc[0]).total_seconds()/86400
    hh = dfs['random_date'].iloc[0].hour
    dd = dfs['random_date'].iloc[0].day
    mm = dfs['random_date'].iloc[0].month
    yy = dfs['random_date'].iloc[0].year
    with open(r'TideFac-Code-Executable/dates.txt', 'w') as fout:
        fout.write(f'{dur:0.3f}\n')
        fout.write(f'{hh:02d},{dd},{mm},{yy}')
    os.system(r'TideFac-Code-Executable/a.out < TideFac-Code-Executable/dates.txt > TideFac-Code-Executable/screen.txt')
    
    aux = pd.read_csv('tide_fac.out', skiprows=9, header = None, delim_whitespace = True,
                           names = [f'node_factor_{int(tc)}', f'eq_arg_{int(tc)}'])
    if itc == 0:
        dfout = aux.copy()
    else:
        dfout = pd.concat([dfout, aux], axis = 1)
dfout.to_pickle(pathin/f'Tide_variables_for_exec{exe_id:02d}.pkl')
# Out:
# 1000it [00:16, 58.86it/s]

# %%
dfout
# Out:
#       node_factor_136  eq_arg_136  node_factor_454  eq_arg_454  \
# M2            1.01415      248.43          0.99864      232.34
# S2            1.00000        0.00          1.00000      300.00
# N2            1.01415      330.31          0.99864      117.67
# K1            0.96982      340.46          1.01924       39.75
# M4            1.02849      136.87          0.99729      104.68
# O1            0.95094      272.14          1.03090      196.49
# M6            1.04304       25.30          0.99593      337.03
# MK3           0.98354      228.89          1.01785      272.09
# S4            1.00000        0.00          1.00000      240.00
# MN4           1.02849      218.75          0.99729      350.02
# NU2           1.01415       56.98          0.99864      281.51
# S6            1.00000        0.00          1.00000      180.00
# MU2           1.01415      138.86          0.99864      166.84
# 2N2           1.01415       52.19          0.99864        3.00
# OO1           0.83374      220.46          1.09547       55.20
# LAMB          1.01415      259.89          0.99864        3.18
# S1            1.00000        0.00          1.00000      330.00
# M1            0.00000       46.56          0.00000      268.11
# J1            0.96360      254.42          1.03591      150.52
# MM            1.04781      278.12          0.99364      114.67
# SSA           1.00000      158.23          1.00000      336.98
# SA            1.00000       79.12          1.00000      168.49
# MSF           1.01415      109.57          0.99864       65.51
# MF            0.89076      244.16          1.06311       19.35
# RHO1          0.95094       80.68          1.03090      245.66
# Q1            0.95094      354.02          1.03090       81.82
# T2            1.00000      203.19          1.00000       53.84
# R2            1.00000      336.81          1.00000        6.16
# 2Q1           0.95094       75.89          1.03090      327.15
# P1            1.00000       10.88          1.00000      251.51
# 2SM2          1.01415      111.57          0.99864        7.66
# M3            1.02139       12.65          0.99806      168.51
# L2            0.00000      335.23          0.00000      160.91
# 2MK3          0.99746      156.41          1.01647       64.93
# K2            0.90953      141.27          1.02778      259.27
# M8            1.05779      273.74          0.99458      209.37
# MS4           1.01415      248.43          0.99864      172.34
#
#       node_factor_607  eq_arg_607  node_factor_622  eq_arg_622  \
# M2            0.99205      330.79          0.98474      180.14
# S2            1.00000      240.00          1.00000      240.00
# N2            0.99205      131.09          0.98474       57.31
# K1            1.03855      158.41          1.05888      287.24
# M4            0.98416      301.59          0.96971        0.27
# O1            1.06212      176.00          1.09504      256.10
# M6            0.97633      272.38          0.95490      180.41
# MK3           1.03029      129.20          1.04272      107.38
# S4            1.00000      120.00          1.00000      120.00
# MN4           0.98416      101.88          0.96971      237.45
# NU2           0.99205      263.40          0.98474      245.07
# S6            1.00000        0.00          1.00000        0.00
# MU2           0.99205       63.69          0.98474      122.24
